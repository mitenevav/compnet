# %%
import numpy as np
import time
from threading import Thread
from main import simulate

from routers import Router, DesignatedRouter

# %%
linear = {
        "nodes": [0, 1, 2, 3, 4],
        "neighbors": [[1], [0, 2], [1, 3], [2, 4], [3]]
    }
circle = {
    "nodes": [0, 1, 2, 3, 4],
    "neighbors": [[4, 1], [0, 2], [1, 3], [2, 4], [3, 0]]
}
star = {
    "nodes": [0, 1, 2, 3, 4],
    "neighbors": [[2], [2], [0, 1, 3, 4], [2], [2]]
}

# %%
# simulate(linear["nodes"], linear["neighbors"])
# simulate(circle["nodes"], circle["neighbors"])
simulate(star["nodes"], circle["neighbors"])
# Out:
# router0 got: "LSU 1->0, 1->2"
#
# router0 got: "LSU 2->1, 2->3"
#
# router1 got: "LSU 2->1, 2->3"
#
# router1 got: "LSU 3->2, 3->4"
#
# router2 got: "LSU 3->2, 3->4"
#
# router0 got: "LSU 3->2, 3->4"
#
# router2 got: "LSU 4->3, 4->0"
# router1 got: "LSU 4->3, 4->0"
#
# router3 got: "LSU 4->3, 4->0"
#
#
# router0 got: "LSU 4->3, 4->0"
#
# shortest ways from 1:
# (1, 0): 1 -> 0
# (1, 1): 1
# (1, 2): 1 -> 2
# (1, 3): 1 -> 2 -> 3
# (1, 4): 1 -> 0 -> 4
#
# shortest ways from 2:
# (2, 0): 2 -> 1 -> 0
# (2, 1): 2 -> 1
# (2, 2): 2
# (2, 3): 2 -> 3
# (2, 4): 2 -> 3 -> 4
#
# shortest ways from 3:
# (3, 0): 3 -> 4 -> 0
# (3, 1): 3 -> 2 -> 1
# (3, 2): 3 -> 2
# (3, 3): 3
# (3, 4): 3 -> 4
#
# shortest ways from 4:
# (4, 0): 4 -> 0
# (4, 1): 4 -> 0 -> 1
# (4, 2): 4 -> 3 -> 2
# (4, 3): 4 -> 3
# (4, 4): 4
#
# shortest ways from 0:
# (0, 0): 0
# (0, 1): 0 -> 1
# (0, 2): 0 -> 1 -> 2
# (0, 3): 0 -> 4 -> 3
# (0, 4): 0 -> 4
#
# router0 got: "LSU 2 dropped"
#
# router4 got: "LSU 2 dropped"
#
# router1 got: "LSU 2 dropped"
#
# router3 got: "LSU 2 dropped"
#
# shortest ways from 1:
# (1, 0): 1 -> 0
# (1, 1): 1
# (1, 2): None
# (1, 3): 1 -> 0 -> 4 -> 3
# (1, 4): 1 -> 0 -> 4
#
# shortest ways from 0:
# (0, 0): 0
# (0, 1): 0 -> 1
# (0, 2): None
# (0, 3): 0 -> 4 -> 3
# (0, 4): 0 -> 4
#
# shortest ways from 4:
# (4, 0): 4 -> 0
# (4, 1): 4 -> 0 -> 1
# (4, 2): None
# (4, 3): 4 -> 3
# (4, 4): 4
#
# shortest ways from 3:
# (3, 0): 3 -> 4 -> 0
# (3, 1): 3 -> 4 -> 0 -> 1
# (3, 2): None
# (3, 3): 3
# (3, 4): 3 -> 4
#
# router0 got: "LSU 4 dropped"
#
# router1 got: "LSU 4 dropped"
# router3 got: "LSU 4 dropped"
#
#
# shortest ways from 0:
# (0, 0): 0
# (0, 1): 0 -> 1
# (0, 2): None
# (0, 3): None
# (0, 4): None
#
# shortest ways from 1:
# (1, 0): 1 -> 0
# (1, 1): 1
# (1, 2): None
# (1, 3): None
# (1, 4): None
#
# shortest ways from 3:
# (3, 0): None
# (3, 1): None
# (3, 2): None
# (3, 3): 3
# (3, 4): None
#
# router0 got: "LSU 2->1, 2->3"
#
# router1 got: "LSU 2->1, 2->3"
#
# router3 got: "LSU 2->1, 2->3"
#
# router0 got: "LSU 1->2"
#
# router0 got: "LSU 3->2"
#
# router1 got: "LSU 3->2"
# router3 got: "LSU 1->2"
#
#
# shortest ways from 2:
# (2, 0): 2 -> 1 -> 0
# (2, 1): 2 -> 1
# (2, 2): 2
# (2, 3): 2 -> 3
# (2, 4): None
#
# router2 got: "LSU 4 dropped"
# shortest ways from 3:
# (3, 0): 3 -> 2 -> 1 -> 0
# (3, 1): 3 -> 2 -> 1
# (3, 2): 3 -> 2
# (3, 3): 3
# (3, 4): None
#
# shortest ways from 0:
# (0, 0): 0
# (0, 1): 0 -> 1
# (0, 2): 0 -> 1 -> 2
# (0, 3): 0 -> 1 -> 2 -> 3
# (0, 4): None
#
# shortest ways from 1:
# (1, 0): 1 -> 0
# (1, 1): 1
# (1, 2): 1 -> 2
# (1, 3): 1 -> 2 -> 3
# (1, 4): None
#
#
# shortest ways from 2:
# (2, 0): 2 -> 1 -> 0
# (2, 1): 2 -> 1
# (2, 2): 2
# (2, 3): 2 -> 3
# (2, 4): None
#
# router2 got: "LSU 1->2"
#
# router2 got: "LSU 3->2"
#
# shortest ways from 2:
# (2, 0): 2 -> 1 -> 0
# (2, 1): 2 -> 1
# (2, 2): 2
# (2, 3): 2 -> 3
# (2, 4): None
